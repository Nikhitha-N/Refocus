# %%
# !pip -q install datasets scikit-image opencv-python

# %%
from datasets import load_dataset
ds = load_dataset("nickpai/coco2017-colorization")  # train + val/test (depending on revision)
print(ds)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/27.5M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# ...
# Generating validation split:   0%|          | 0/5000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['license', 'file_name', 'coco_url', 'height', 'width', 'date_captured', 'flickr_url', 'image_id', 'ids', 'captions'],
# ...

# %%
# !pip -q install datasets scikit-image opencv-python requests

# %%
from datasets import load_dataset
ds = load_dataset("nickpai/coco2017-colorization")
train_meta, val_meta = ds["train"], ds["validation"]

# %%
import os, io, time, random, requests, numpy as np, torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from skimage import color
from pathlib import Path

CACHE_DIR = Path("/content/coco_cache"); CACHE_DIR.mkdir(parents=True, exist_ok=True)

# %%
# ====================== CONFIG ======================
CROP        = 256              # final side length
RESIZE_MIN  = 224              # random short-side (train)
RESIZE_MAX  = 288
BATCH_SIZE  = 16               # adjust per GPU
NUM_WORKERS = 2
VAL_FRAC    = 0.05             # from COCO train2017
SEED        = 42

# ================== SETUP & METADATA =================
# !pip -q install datasets scikit-image opencv-python requests
from datasets import load_dataset
ds = load_dataset("nickpai/coco2017-colorization")
train_meta, val_meta = ds["train"], ds["validation"]  # we'll split train_meta into train/val; val_meta becomes test

from pathlib import Path
CACHE_DIR = Path("/content/coco_cache"); CACHE_DIR.mkdir(parents=True, exist_ok=True)

# =================== HELPERS =========================
import io, time, requests, numpy as np, torch, random, cv2
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from skimage import color

def fetch_image(url, retries=3, timeout=15):
    """Download with small on-disk cache (by filename)."""
    fname = url.split("/")[-1]
    fpath = CACHE_DIR / fname
    if fpath.exists():
        return Image.open(fpath).convert("RGB")
    err = None
    for k in range(retries):
        try:
            r = requests.get(url, timeout=timeout)
            r.raise_for_status()
            img = Image.open(io.BytesIO(r.content)).convert("RGB")
            img.save(fpath)  # cache
            return img
        except Exception as e:
            err = e
            time.sleep(1.0*(k+1))
    raise err

def random_resize_then_center_crop(img_np, out_size, lo=RESIZE_MIN, hi=RESIZE_MAX):
    """Random short-side resize ∈ [lo,hi], keep aspect; center-square crop; resize to out_size."""
    h, w = img_np.shape[:2]
    s = np.random.randint(lo, hi+1)
    if h < w:
        new_h, new_w = s, int(round(w*s/h))
    else:
        new_h, new_w = int(round(h*s/w)), s
    rs = cv2.resize(img_np, (new_w, new_h), interpolation=cv2.INTER_CUBIC)
    h2, w2 = rs.shape[:2]
    side = min(h2, w2)
    y0 = (h2 - side)//2; x0 = (w2 - side)//2
    sq = rs[y0:y0+side, x0:x0+side]
    return cv2.resize(sq, (out_size, out_size), interpolation=cv2.INTER_CUBIC)

def to_L_ab_tensors(img_np):
    """
    Input: img_np as RGB float in [0,1].
    Output: L in [0,1], ab in [-1,1], both as CHW torch tensors (1xHxW, 2xHxW).
    """
    # ensure strict [0,1] before Lab
    rgb = np.clip(img_np, 0.0, 1.0).astype(np.float32)
    lab = color.rgb2lab(rgb).astype(np.float32)   # L[0..100], a/b ~ [-110,110]

    L  = lab[..., :1] / 100.0
    ab = lab[..., 1:] / 110.0

    # clip to target ranges to avoid tiny overshoots from interpolation/rounding
    L  = np.clip(L,  0.0, 1.0)
    ab = np.clip(ab, -1.0, 1.0)

    L  = torch.from_numpy(L).permute(2,0,1).contiguous()   # (1,H,W)
    ab = torch.from_numpy(ab).permute(2,0,1).contiguous()  # (2,H,W)
    return L, ab

# =================== DATASET =========================
class CocoURLColorizeFromURLs(Dataset):
    def __init__(self, urls, crop=CROP, train=True, hflip=True,
                 resize_lo=RESIZE_MIN, resize_hi=RESIZE_MAX):
        self.urls = urls
        self.crop = crop
        self.train = train
        self.hflip = (hflip and train)
        self.lo, self.hi = resize_lo, resize_hi

    def __len__(self): return len(self.urls)

    def __getitem__(self, i):
        url = self.urls[i]
        # fetch & to np RGB [0,1]
        try:
            img = fetch_image(url)
        except Exception:
            # fallback on occasional broken URL
            j = random.randrange(len(self.urls))
            img = fetch_image(self.urls[j])
        img_np = np.asarray(img, dtype=np.float32) / 255.0

        if self.train:
            img_np = random_resize_then_center_crop(img_np, self.crop, self.lo, self.hi)
            if random.random() < 0.5:
                img_np = img_np[:, ::-1, :].copy()
        else:
            # deterministic center-square + resize
            h, w = img_np.shape[:2]; side = min(h, w)
            y0 = (h - side)//2; x0 = (w - side)//2
            img_np = img_np[y0:y0+side, x0:x0+side]
            img_np = cv2.resize(img_np, (self.crop, self.crop), interpolation=cv2.INTER_CUBIC)

        L, ab = to_L_ab_tensors(img_np)
        return {"L": L, "ab": ab, "url": url}

# =================== SPLITS =========================
# Split COCO train2017 into train/val; use official val2017 as TEST
urls_all = [row["coco_url"] for row in train_meta]
random.Random(SEED).shuffle(urls_all)
n = len(urls_all); n_val = int(round(VAL_FRAC * n))
urls_val = urls_all[:n_val]
urls_train = urls_all[n_val:]
urls_test = [row["coco_url"] for row in val_meta]  # official val2017 as test

print(f"Train: {len(urls_train)} | Val: {len(urls_val)} | Test: {len(urls_test)}")

# =================== LOADERS ========================
def collate(batch):
    L  = torch.stack([b["L"]  for b in batch], dim=0)
    ab = torch.stack([b["ab"] for b in batch], dim=0)
    return {"L": L, "ab": ab}

train_ds = CocoURLColorizeFromURLs(urls_train, crop=CROP, train=True,  hflip=True)
val_ds   = CocoURLColorizeFromURLs(urls_val,   crop=CROP, train=False, hflip=False)
test_ds  = CocoURLColorizeFromURLs(urls_test,  crop=CROP, train=False, hflip=False)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=NUM_WORKERS, pin_memory=True,
                          collate_fn=collate, drop_last=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True,
                          collate_fn=collate)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True,
                          collate_fn=collate)

print("Batches -> train:", len(train_loader), "| val:", len(val_loader), "| test:", len(test_loader))

# ================= SANITY CHECK =====================
batch = next(iter(train_loader))
L, ab = batch["L"], batch["ab"]
print("L:",  L.shape,  f"[{L.min().item():.3f}, {L.max().item():.3f}]")
print("ab:", ab.shape, f"[{ab.min().item():.3f}, {ab.max().item():.3f}]")
# Out:
# Train: 106655 | Val: 5613 | Test: 5000
# Batches -> train: 6665 | val: 351 | test: 313
# L: torch.Size([16, 1, 256, 256]) [0.000, 1.000]
# ab: torch.Size([16, 2, 256, 256]) [-0.672, 0.859]

# %%
# ================== SPEED & SANITY ==================
import torch, numpy as np, matplotlib.pyplot as plt
from torch import amp
torch.backends.cudnn.benchmark = True
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", torch.cuda.get_device_name(0) if device.type=="cuda" else "CPU")

# ================== HELPER: Lab->RGB =================
from skimage import color
@torch.no_grad()
def lab_to_rgb01(L01, ab_scaled):
    # L01:[B,1,H,W] in [0,1], ab_scaled:[B,2,H,W] in [-1,1] (approx lab scale)
    L = (L01*100.0).clamp(0,100).permute(0,2,3,1).cpu().numpy()        # B,H,W,1
    a = (ab_scaled[:,0:1]*110.0).permute(0,2,3,1).cpu().numpy()
    b = (ab_scaled[:,1:2]*110.0).permute(0,2,3,1).cpu().numpy()
    Lab = np.concatenate([L,a,b], axis=3)
    rgb = np.stack([color.lab2rgb(Lab[i]) for i in range(Lab.shape[0])])
    return torch.from_numpy(rgb).permute(0,3,1,2).float().clamp(0,1)

# ============ UNPAIRED ITERATOR (finite, fast) ============
def iterate_unpaired(dl1, dl2):
    # Zips the two finite loaders; stops at the shorter one.
    for b1, b2 in zip(dl1, dl2):
        X = b1["L"].repeat(1,3,1,1)                # gray domain: 3×L
        Y = lab_to_rgb01(b2["L"], b2["ab"])        # color domain: RGB
        yield {"X": X, "Y": Y, "Lx": b1["L"]}

train_unpaired = iterate_unpaired(train_loader, train_loader)
val_unpaired   = iterate_unpaired(val_loader,   val_loader)
# Out:
# Device: Tesla T4

# %%
# =================== MODELS (lighter) ====================
import torch.nn as nn, torch.nn.functional as F

class ResnetBlock(nn.Module):
    def __init__(self,c):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(c,c,3,1,1,bias=False), nn.InstanceNorm2d(c), nn.ReLU(True),
            nn.Conv2d(c,c,3,1,1,bias=False), nn.InstanceNorm2d(c)
        )
    def forward(self,x): return x + self.net(x)

class ResnetGen(nn.Module):
    def __init__(self, in_ch=3, out_ch=3, ngf=64, blocks=6):  # blocks=6 (was 9) for speed
        super().__init__()
        L = [
            nn.Conv2d(in_ch, ngf, 7, 1, 3, bias=False), nn.InstanceNorm2d(ngf), nn.ReLU(True),
            nn.Conv2d(ngf, ngf*2, 3, 2, 1, bias=False), nn.InstanceNorm2d(ngf*2), nn.ReLU(True),
            nn.Conv2d(ngf*2, ngf*4, 3, 2, 1, bias=False), nn.InstanceNorm2d(ngf*4), nn.ReLU(True),
        ]
        L += [ResnetBlock(ngf*4) for _ in range(blocks)]
        L += [
            nn.ConvTranspose2d(ngf*4, ngf*2, 3, 2, 1, output_padding=1, bias=False),
            nn.InstanceNorm2d(ngf*2), nn.ReLU(True),
            nn.ConvTranspose2d(ngf*2, ngf, 3, 2, 1, output_padding=1, bias=False),
            nn.InstanceNorm2d(ngf), nn.ReLU(True),
            nn.Conv2d(ngf, out_ch, 7, 1, 3), nn.Tanh()
        ]
        self.net = nn.Sequential(*L)
    def forward(self,x): return self.net(x)

class NLayerDis(nn.Module):
    def __init__(self, in_ch=3, ndf=64, n_layers=3):
        super().__init__()
        L=[nn.Conv2d(in_ch, ndf, 4, 2, 1), nn.LeakyReLU(0.2, True)]
        c=ndf
        for _ in range(1, n_layers):
            c2=min(c*2,512)
            L += [nn.Conv2d(c, c2, 4, 2, 1, bias=False), nn.InstanceNorm2d(c2), nn.LeakyReLU(0.2, True)]
            c=c2
        L += [nn.Conv2d(c, 1, 4, 1, 1)]
        self.net = nn.Sequential(*L)
    def forward(self,x): return self.net(x)

G_XY = ResnetGen(3,3, ngf=64, blocks=6).to(device)  # gray3 -> color
G_YX = ResnetGen(3,3, ngf=64, blocks=6).to(device)  # color -> gray3
D_X  = NLayerDis(3).to(device)
D_Y  = NLayerDis(3).to(device)

# %%
# ==================== OPTIM & LOSS ====================
optG  = torch.optim.AdamW(list(G_XY.parameters())+list(G_YX.parameters()), lr=2e-4, betas=(0.5,0.999))
optDX = torch.optim.AdamW(D_X.parameters(), lr=2e-4, betas=(0.5,0.999))
optDY = torch.optim.AdamW(D_Y.parameters(), lr=2e-4, betas=(0.5,0.999))

L1 = nn.L1Loss()
to_n1p1 = lambda x: x*2-1
to_01   = lambda x: (x+1)/2
lsgan_g = lambda d: 0.5*((d-1)**2).mean()
def lsgan_d(dr, df): return 0.5*((dr-1)**2).mean() + 0.5*(df**2).mean()

λ_cyc, λ_id = 10.0, 5.0
scaler = amp.GradScaler(enabled=(device.type=="cuda"))

# ============== TRAIN: CAPPED STEPS & LOGS =============
EPOCHS    = 15        # smoke test first; increase after
MAX_STEPS = 400        # limit batches/epoch so it finishes quickly
LOG_EVERY = 50

for ep in range(1, EPOCHS+1):
    G_XY.train(); G_YX.train(); D_X.train(); D_Y.train()
    g_run = d_run = n_seen = 0

    for step, batch in enumerate(train_unpaired, start=1):
        X = batch["X"].to(device)     # [B,3,H,W] in [0,1]
        Y = batch["Y"].to(device)     # [B,3,H,W] in [0,1]
        Xn, Yn = to_n1p1(X), to_n1p1(Y)

        # ---- G step ----
        with amp.autocast(device_type=device.type, enabled=(device.type=="cuda")):
            fake_Y = G_XY(Xn); fake_X = G_YX(Yn)
            g_adv  = lsgan_g(D_Y(fake_Y)) + lsgan_g(D_X(fake_X))
            rec_X  = G_YX(fake_Y);      rec_Y  = G_XY(fake_X)
            g_cyc  = L1(rec_X, Xn) + L1(rec_Y, Yn)
            id_Y   = G_XY(Yn);          id_X   = G_YX(Xn)
            g_id   = L1(id_Y, Yn) + L1(id_X, Xn)
            g_tot  = g_adv + λ_cyc*g_cyc + λ_id*g_id
        optG.zero_grad(set_to_none=True)
        scaler.scale(g_tot).backward(); scaler.step(optG); scaler.update()

        # ---- D_Y step ----
        with amp.autocast(device_type=device.type, enabled=(device.type=="cuda")):
            dY_real = D_Y(Yn)
            fake_Yd = G_XY(Xn).detach()
            dY_fake = D_Y(fake_Yd)
            dY_loss = lsgan_d(dY_real, dY_fake)
        optDY.zero_grad(set_to_none=True)
        scaler.scale(dY_loss).backward(); scaler.step(optDY); scaler.update()

        # ---- D_X step ----
        with amp.autocast(device_type=device.type, enabled=(device.type=="cuda")):
            dX_real = D_X(Xn)
            fake_Xd = G_YX(Yn).detach()
            dX_fake = D_X(fake_Xd)
            dX_loss = lsgan_d(dX_real, dX_fake)
        optDX.zero_grad(set_to_none=True)
        scaler.scale(dX_loss).backward(); scaler.step(optDX); scaler.update()

        bsz = X.size(0)
        n_seen += bsz
        g_run += g_tot.item() * bsz
        d_run += ((dX_loss.item() + dY_loss.item()) * 0.5) * bsz

        if step % LOG_EVERY == 0:
            print(f"ep {ep} step {step}/{MAX_STEPS} | G {g_run/n_seen:.4f} | D {d_run/n_seen:.4f}")

        if step >= MAX_STEPS:
            break

    print(f"Epoch {ep:02d} done | G {g_run/n_seen:.4f} | D {d_run/n_seen:.4f}")

# ================ SAVE GENERATORS =================
torch.save(G_XY.state_dict(), "/content/cyclegan_G_XY.pth")
torch.save(G_YX.state_dict(), "/content/cyclegan_G_YX.pth")
print("Saved: /content/cyclegan_G_XY.pth and G_YX.pth")
# Out:
# ep 1 step 50/400 | G 9.3081 | D 0.2887
# ep 1 step 100/400 | G 8.3853 | D 0.2640
# ep 1 step 150/400 | G 7.8649 | D 0.2533
# ep 1 step 200/400 | G 7.5082 | D 0.2457
# ep 1 step 250/400 | G 7.2710 | D 0.2383
# ep 1 step 300/400 | G 7.0615 | D 0.2317
# ep 1 step 350/400 | G 6.8910 | D 0.2260
# ep 1 step 400/400 | G 6.7626 | D 0.2202
# Epoch 01 done | G 6.7626 | D 0.2202
# ep 2 step 50/400 | G 5.7182 | D 0.1673
# ep 2 step 100/400 | G 5.7485 | D 0.1672
# ep 2 step 150/400 | G 5.7266 | D 0.1644
# ep 2 step 200/400 | G 5.6890 | D 0.1618
# ep 2 step 250/400 | G 5.6900 | D 0.1596
# ep 2 step 300/400 | G 5.6785 | D 0.1589
# ep 2 step 350/400 | G 5.6524 | D 0.1615
# ep 2 step 400/400 | G 5.6087 | D 0.1588
# Epoch 02 done | G 5.6087 | D 0.1588
# ep 3 step 50/400 | G 5.3818 | D 0.1504
# ep 3 step 100/400 | G 5.4405 | D 0.1486
# ep 3 step 150/400 | G 5.3640 | D 0.1536
# ep 3 step 200/400 | G 5.4057 | D 0.2039
# ep 3 step 250/400 | G 5.2763 | D 0.2066
# ep 3 step 300/400 | G 5.1779 | D 0.2062
# ...

# %%
import matplotlib.pyplot as plt, torch

G_XY.eval()
@torch.no_grad()
def preview_colorizer(sample_loader, n=6):
    b = next(iter(sample_loader))
    L = b["L"][:n].to(device)                  # [n,1,256,256]
    gray3 = L.repeat(1,3,1,1)
    rgb_pred = (G_XY(gray3*2-1)*0.5+0.5).clamp(0,1).cpu()

    fig, axs = plt.subplots(n, 2, figsize=(6, 3*n))
    for i in range(n):
        axs[i,0].imshow(L[i,0].cpu(), cmap='gray', vmin=0, vmax=1); axs[i,0].set_title("Gray"); axs[i,0].axis('off')
        axs[i,1].imshow(rgb_pred[i].permute(1,2,0));                axs[i,1].set_title("CycleGAN Color"); axs[i,1].axis('off')
    plt.tight_layout(); plt.show()

preview_colorizer(val_loader, n=6)

# %%
# If you restarted, reload:
# G_XY.load_state_dict(torch.load("/content/cyclegan_G_XY.pth", map_location=device)); G_XY.eval()

import torch, numpy as np, torch.nn.functional as F
from skimage import color
from skimage.color import deltaE_ciede2000

@torch.no_grad()
def lab_to_rgb01(L01, ab_scaled):
    L  = (L01*100.0).clamp(0,100).permute(0,2,3,1).cpu().numpy()
    a  = (ab_scaled[:,0:1]*110.0).permute(0,2,3,1).cpu().numpy()
    b  = (ab_scaled[:,1:2]*110.0).permute(0,2,3,1).cpu().numpy()
    Lab = np.concatenate([L,a,b], axis=3)
    rgb = np.stack([color.lab2rgb(Lab[i]) for i in range(Lab.shape[0])])
    return torch.from_numpy(rgb).permute(0,3,1,2).float().clamp(0,1)

def psnr_rgb(yhat, y):
    mse = ((yhat - y)**2).flatten(1).mean(1)
    return torch.where(mse==0, torch.full_like(mse, 99.0), 10*torch.log10(1.0/mse))

def ssim_3c(yhat, y):
    C1, C2 = 0.01**2, 0.03**2
    def pool(z): return F.avg_pool2d(z, 3, 1, 1)
    mu_x, mu_y = pool(yhat), pool(y)
    sx  = pool(yhat*yhat) - mu_x**2
    sy  = pool(y*y)       - mu_y**2
    sxy = pool(yhat*y)    - mu_x*mu_y
    s = ((2*mu_x*mu_y + C1)*(2*sxy + C2))/((mu_x**2 + mu_y**2 + C1)*(sx + sy + C2))
    return s.flatten(1).mean(1)

@torch.no_grad()
def eval_color_metrics(model, loader, tau=2.0, max_batches=200):
    model.eval()
    mae_rgb=[]; mse_rgb=[]; mae_ab=[]; mse_ab=[]
    de_sum=0; de_cnt=0; de_pix_ok=0; de_pix_tot=0; de_img_ok=0; de_img_tot=0

    for i, b in enumerate(loader, 1):
        L, ab = b["L"].to(device), b["ab"].to(device)
        rgb_gt = lab_to_rgb01(L, ab).to(device)
        gray3  = L.repeat(1,3,1,1)
        rgb_pr = (model(gray3*2-1)*0.5+0.5).clamp(0,1)

        mae_rgb.append(torch.mean(torch.abs(rgb_pr-rgb_gt)).item())
        mse_rgb.append(torch.mean((rgb_pr-rgb_gt)**2).item())

        # pred RGB -> Lab -> ab (scaled)
        pr_lab = []
        for j in range(rgb_pr.size(0)):
            pr_lab.append(color.rgb2lab(rgb_pr[j].permute(1,2,0).cpu().numpy()).astype(np.float32))
        pr_lab = torch.from_numpy(np.stack(pr_lab)).to(device)  # [B,H,W,3]
        ab_pr  = (pr_lab[...,1:3].permute(0,3,1,2)/110.0).clamp(-1,1)

        mae_ab.append(torch.mean(torch.abs(ab_pr - ab)).item())
        mse_ab.append(torch.mean((ab_pr - ab)**2).item())

        # ΔE2000 + perceptual accuracy
        L_gt  = (L*100.0).cpu().numpy()
        ab_gt = (ab*110.0).cpu().numpy()
        Lab_gt = np.concatenate([L_gt, ab_gt], axis=1).transpose(0,2,3,1)

        rgb_np = rgb_pr.cpu().numpy()
        Lab_pr = np.stack([color.rgb2lab(rgb_np[j].transpose(1,2,0)).astype(np.float32)
                           for j in range(rgb_np.shape[0])])

        for j in range(Lab_pr.shape[0]):
            de = deltaE_ciede2000(Lab_gt[j], Lab_pr[j])
            de_sum += float(de.mean()) * de.size
            de_cnt += de.size
            de_pix_ok += int((de <= tau).sum())
            de_pix_tot += de.size
            de_img_ok  += float(de.mean() <= tau)
            de_img_tot += 1

        if max_batches and i>=max_batches: break

    out = {
        "PSNR": float(torch.cat([
            psnr_rgb((torch.tensor(rgb_pr.cpu())), (torch.tensor(rgb_gt.cpu())))
        ]).mean().item()) if False else None,  # optional quick PSNR batch-wise
        "MAE_RGB": float(np.mean(mae_rgb)),
        "MSE_RGB": float(np.mean(mse_rgb)),
        "MAE_ab":  float(np.mean(mae_ab)),
        "MSE_ab":  float(np.mean(mse_ab)),
        "DeltaE_mean": float(de_sum/max(1,de_cnt)),
        "DeltaE_acc@2.0": float(de_pix_ok/max(1,de_pix_tot)),
        "DeltaE_img_pass@2.0": float(de_img_ok/max(1,de_img_tot)),
    }
    print(
        f"MAE_RGB {out['MAE_RGB']:.4f}  MSE_RGB {out['MSE_RGB']:.6f}  "
        f"MAE_ab {out['MAE_ab']:.4f}  MSE_ab {out['MSE_ab']:.6f}\n"
        f"ΔE_mean {out['DeltaE_mean']:.2f}  ΔE@2.0 {out['DeltaE_acc@2.0']*100:.2f}%  "
        f"ΔE img pass@2.0 {out['DeltaE_img_pass@2.0']*100:.2f}%"
    )
    return out

_ = eval_color_metrics(G_XY, test_loader, tau=2.0, max_batches=100)
# Out:
# MAE_RGB 0.0786  MSE_RGB 0.012929  MAE_ab 0.1086  MSE_ab 0.025624
# ΔE_mean 14.28  ΔE@2.0 2.35%  ΔE img pass@2.0 0.00%

# %%
import numpy as np, torch, matplotlib.pyplot as plt
from collections import defaultdict
from skimage import color
from skimage.color import deltaE_ciede2000

@torch.no_grad()
def eval_color_metrics_batched(model, loader, tau=2.0, max_batches=None):
    model.eval()
    logs = defaultdict(list)

    def lab_to_rgb01(L01, ab_scaled):
        L  = (L01*100.0).clamp(0,100).permute(0,2,3,1).cpu().numpy()
        a  = (ab_scaled[:,0:1]*110.0).permute(0,2,3,1).cpu().numpy()
        b  = (ab_scaled[:,1:2]*110.0).permute(0,2,3,1).cpu().numpy()
        Lab = np.concatenate([L,a,b], axis=3)
        rgb = np.stack([color.lab2rgb(Lab[i]) for i in range(Lab.shape[0])])
        return torch.from_numpy(rgb).permute(0,3,1,2).float().clamp(0,1)

    step = 0
    for b in loader:
        step += 1
        L, ab = b["L"].to(device), b["ab"].to(device)
        rgb_gt = lab_to_rgb01(L, ab).to(device)
        gray3  = L.repeat(1,3,1,1)
        rgb_pr = (model(gray3*2-1)*0.5+0.5).clamp(0,1)

        mae_rgb = torch.mean(torch.abs(rgb_pr - rgb_gt)).item()
        mse_rgb = torch.mean((rgb_pr - rgb_gt)**2).item()

        # ab error via RGB→Lab
        pr_lab = []
        for j in range(rgb_pr.size(0)):
            pr_lab.append(color.rgb2lab(rgb_pr[j].permute(1,2,0).cpu().numpy()).astype(np.float32))
        pr_lab = torch.from_numpy(np.stack(pr_lab)).to(device)  # [B,H,W,3]
        ab_pr  = (pr_lab[...,1:3].permute(0,3,1,2)/110.0).clamp(-1,1)
        mae_ab = torch.mean(torch.abs(ab_pr - ab)).item()
        mse_ab = torch.mean((ab_pr - ab)**2).item()

        # ΔE2000
        L_gt  = (L*100.0).cpu().numpy()
        ab_gt = (ab*110.0).cpu().numpy()
        Lab_gt = np.concatenate([L_gt, ab_gt], axis=1).transpose(0,2,3,1)

        rgb_np = rgb_pr.cpu().numpy()
        Lab_pr = np.stack([color.rgb2lab(rgb_np[j].transpose(1,2,0)).astype(np.float32)
                           for j in range(rgb_np.shape[0])])
        de = np.stack([deltaE_ciede2000(Lab_gt[k], Lab_pr[k]) for k in range(Lab_pr.shape[0])])
        de_mean = float(de.mean())
        de_acc2 = float((de <= tau).mean())

        # log per-batch
        logs["MAE_RGB"].append(mae_rgb)
        logs["MSE_RGB"].append(mse_rgb)
        logs["MAE_ab"].append(mae_ab)
        logs["MSE_ab"].append(mse_ab)
        logs["DeltaE_mean"].append(de_mean)
        logs["DeltaE_acc@2.0"].append(de_acc2)

        if max_batches and step >= max_batches: break

    return {k: np.array(v) for k, v in logs.items()}

# ---- run & plot ----
logs = eval_color_metrics_batched(G_XY, test_loader, tau=2.0, max_batches=100)

# %%
def plot_curves(logs, keys=("MAE_RGB","MAE_ab","DeltaE_mean")):
    plt.figure(figsize=(10,5))
    for k in keys:
        y = logs[k]
        # simple moving average for readability
        win = max(1, len(y)//20)
        if win > 1:
            y_smooth = np.convolve(y, np.ones(win)/win, mode="valid")
            x = np.arange(len(y_smooth)) + win//2
            plt.plot(x, y_smooth, label=f"{k} (MA{win})")
        plt.plot(y, alpha=0.25, linestyle="--")
    plt.xlabel("Test batch index")
    plt.ylabel("Value")
    plt.title("Test metrics per batch")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_curves(logs, keys=("MAE_RGB","MAE_ab","DeltaE_mean"))

# %%
from google.colab import files
files.download('/content/cyclegan_G_XY.pth')  # repeat for G_YX

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# !mkdir -p "/content/drive/MyDrive/REFocus_models"
# !cp /content/cyclegan_G_XY.pth "/content/drive/MyDrive/REFocus_models/"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2116171499.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive', force_remount=True)
#       3
#       4 get_ipython().system('mkdir -p "/content/drive/MyDrive/REFocus_models"')
#       5 get_ipython().system('cp /content/cyclegan_G_XY.pth "/content/drive/MyDrive/REFocus_models/"')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# ...

# %% [markdown]
# ## New Model

# %%
# !pip install datasets pillow torchvision matplotlib

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt

# ============================
# 2. LOAD SMALL DATASET (CIFAR-10)
# ============================
(x_train, _), (x_test, _) = tf.keras.datasets.cifar10.load_data()

# Normalize to [0,1]
x_train = x_train.astype("float32") / 255.
x_test = x_test.astype("float32") / 255.

# Convert RGB → GRAY
x_train_gray = tf.image.rgb_to_grayscale(x_train)
x_test_gray = tf.image.rgb_to_grayscale(x_test)

print("Train shapes:", x_train_gray.shape, x_train.shape)
print("Test shapes:", x_test_gray.shape, x_test.shape)
# Out:
# Train shapes: (50000, 32, 32, 1) (50000, 32, 32, 3)
# Test shapes: (10000, 32, 32, 1) (10000, 32, 32, 3)

# %%
# ============================
# 3. BUILD A SMALL U-NET
# ============================
def unet_colorization(input_shape=(32,32,1)):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1 = layers.Conv2D(32, 3, activation="relu", padding="same")(inputs)
    p1 = layers.MaxPooling2D()(c1)

    c2 = layers.Conv2D(64, 3, activation="relu", padding="same")(p1)
    p2 = layers.MaxPooling2D()(c2)

    # Bottleneck
    bn = layers.Conv2D(128, 3, activation="relu", padding="same")(p2)

    # Decoder
    u1 = layers.UpSampling2D()(bn)
    u1 = layers.Concatenate()([u1, c2])
    c3 = layers.Conv2D(64, 3, activation="relu", padding="same")(u1)

    u2 = layers.UpSampling2D()(c3)
    u2 = layers.Concatenate()([u2, c1])
    c4 = layers.Conv2D(32, 3, activation="relu", padding="same")(u2)

    outputs = layers.Conv2D(3, 1, activation="sigmoid")(c4)

    model = models.Model(inputs, outputs)
    return model

model = unet_colorization()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 32, 32, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │        320 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ conv2d_6[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
# ============================
# 4. COMPILE
# ============================
model.compile(optimizer="adam", loss="mse")

# ============================
# 5. TRAIN
# ============================
history = model.fit(
    x_train_gray,
    x_train,
    validation_data=(x_test_gray, x_test),
    epochs=100,
    batch_size=64
)
# Out:
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 11/100
# ...

# %%
import numpy as np
from skimage.metrics import peak_signal_noise_ratio, structural_similarity
from tqdm import tqdm

# Evaluate on a subset
N = 300   # number of test samples to evaluate
indices = np.random.choice(len(x_test_gray), N, replace=False)

psnr_list, ssim_list, mse_list = [], [], []

for i in tqdm(indices, desc="Evaluating"):
    gray = x_test_gray[i:i+1]
    pred = model.predict(gray, verbose=0)[0]
    gt   = x_test[i]

    mse  = np.mean((pred - gt) ** 2)
    psnr = peak_signal_noise_ratio(gt, pred, data_range=1.0)
    ssim = structural_similarity(gt, pred, channel_axis=2, data_range=1.0)

    mse_list.append(mse)
    psnr_list.append(psnr)
    ssim_list.append(ssim)

print("\n===== TEST RESULTS (300 samples) =====")
print(f"Average MSE  : {np.mean(mse_list):.4f}")
print(f"Average PSNR : {np.mean(psnr_list):.2f} dB")
print(f"Average SSIM : {np.mean(ssim_list):.4f}")
# Out:
# Evaluating: 100%|██████████| 300/300 [00:19<00:00, 15.76it/s]
# ===== TEST RESULTS (300 samples) =====
# Average MSE  : 0.0054
# Average PSNR : 24.32 dB
# Average SSIM : 0.9180

# %%
import matplotlib.pyplot as plt

# Assuming you have the history object from model.fit()
# Example:
# history = model.fit(...)

train_loss = history.history['loss']
val_loss = history.history.get('val_loss')  # safe access

plt.figure(figsize=(8,5))
plt.plot(train_loss, label="Train Loss", linewidth=2)
if val_loss:
    plt.plot(val_loss, label="Validation Loss", linewidth=2)

plt.title("Training vs Validation Loss", fontsize=14)
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
model.save("colorization_model.h5")
print("Model saved!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved!
